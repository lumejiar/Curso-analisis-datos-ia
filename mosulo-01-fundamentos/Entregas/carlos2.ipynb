# %% [markdown]
# <a href="https://colab.research.google.com/github/lumejiar/Curso-analisis-datos-ia/blob/main/mosulo-01-fundamentos/Entregas/carlos2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la Ciencia de Datos
#
# Bienvenido al curso **Introducción a la Ciencia de Datos**.
#
# La ciencia de datos es una disciplina que combina matemáticas, estadística, programación y conocimiento del dominio para transformar datos en información útil para la toma de decisiones.
#
# Actualmente, empresas, gobiernos, investigadores y organizaciones generan enormes cantidades de datos. La capacidad de analizarlos permite descubrir patrones, realizar predicciones y automatizar procesos.

# %% [markdown]
# ## ¿Por qué estudiar Ciencia de Datos?
#
# La ciencia de datos permite:
#
# - Analizar grandes volúmenes de información.
# - Identificar tendencias y comportamientos.
# - Construir modelos predictivos.
# - Automatizar tareas de análisis.
# - Apoyar la toma de decisiones basada en evidencia.
#
# ### Ejemplos de aplicación
#
# - Predicción de ventas.
# - Diagnóstico médico asistido por computador.
# - Sistemas de recomendación.
# - Detección de fraude.
# - Análisis de redes sociales.
# - Optimización de procesos industriales.

# %% [markdown]
# ## Tu primer programa en Python
#
# Python es uno de los lenguajes más utilizados en ciencia de datos debido a su simplicidad y a la gran cantidad de bibliotecas disponibles.

# %%
print("Hola Ciencia de Datos")
# Out:
# Hola Ciencia de Datos

# %% [markdown]
# ## Trabajando con datos
#
# Los datos pueden almacenarse en listas, tablas o bases de datos. Empezaremos con una lista sencilla.

# %%
temperaturas = [25, 27, 24, 30, 28, 29, 26]

print("Temperaturas:", temperaturas)
print("Máxima:", max(temperaturas))
print("Mínima:", min(temperaturas))
print("Promedio:", sum(temperaturas)/len(temperaturas))
# Out:
# Temperaturas: [25, 27, 24, 30, 28, 29, 26]
# Máxima: 30
# Mínima: 24
# Promedio: 27.0

# %% [markdown]
# ## Introducción a Pandas
#
# Pandas es una de las bibliotecas más importantes para el análisis de datos.

# %%
import pandas as pd

datos = pd.DataFrame({
    "Nombre": ["Ana", "Juan", "María", "Carlos"],
    "Edad": [20, 25, 22, 30],
    "Ciudad": ["Cali", "Bogotá", "Medellín", "Cali"]
})

datos

# %% [markdown]
# ## Estadística básica
#
# La estadística es una herramienta fundamental para resumir y comprender datos.

# %%
datos_numericos = [12, 15, 18, 20, 25, 30, 35]

media = sum(datos_numericos)/len(datos_numericos)

print("Media:", media)
print("Máximo:", max(datos_numericos))
print("Mínimo:", min(datos_numericos))

# %% [markdown]
# ## Visualización de datos
#
# Una imagen puede revelar patrones difíciles de detectar en una tabla.

# %%
import matplotlib.pyplot as plt

ventas = [15, 18, 22, 30, 28, 35]

plt.plot(ventas)
plt.title("Ventas mensuales")
plt.xlabel("Mes")
plt.ylabel("Ventas")
plt.show()

# %% [markdown]
# ## ¿Qué aprenderás en este curso?
#
# Al finalizar podrás:
#
# 1. Programar en Python para análisis de datos.
# 2. Manipular conjuntos de datos usando Pandas.
# 3. Crear visualizaciones informativas.
# 4. Aplicar conceptos básicos de estadística.
# 5. Limpiar y preparar datos reales.
# 6. Construir modelos básicos de aprendizaje automático.
# 7. Comunicar resultados mediante informes y gráficos.
#
# ### Proyecto típico
#
# Podrás tomar una base de datos real, limpiarla, analizarla, visualizar tendencias y construir modelos predictivos para responder preguntas de interés.

# %% [markdown]
# # Conclusión
#
# La ciencia de datos es una de las áreas con mayor crecimiento en la actualidad. Combina herramientas matemáticas y computacionales para extraer conocimiento a partir de los datos.
#
# Este cuaderno es una introducción al camino que recorrerás durante el curso.

# %% [markdown]
# Voya modificar como estudiante.

# %%
2+2
# Out:
# 4

# %%
5+5
# Out:
# 10
