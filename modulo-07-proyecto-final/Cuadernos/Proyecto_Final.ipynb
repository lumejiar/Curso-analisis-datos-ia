# %% [markdown]
# # Módulo 7: Proyecto Final
#
# Curso: Ciencia de Datos y Analítica Avanzada
#
# Integración de análisis y visualización. Este notebook es la plantilla base para tu proyecto integrador.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Definición del problema
#
# _Describe el problema, la fuente de datos y la pregunta de investigación._

# %% [markdown]
# ## 2. Limpieza y análisis exploratorio de datos (EDA)
#
# _Entrega de la Semana 8._

# %% [markdown]
# ## 3. Visualización y dashboard
#
# _Visualizaciones clave y/o enlace al dashboard._

# %% [markdown]
# ## 4. Modelado predictivo
#
# _Entrega de la Semana 12: modelo preliminar y resultados._

# %% [markdown]
# ## 5. Interpretación de resultados y conclusiones
#
# _Entrega de la Semana 16: informe final, código reproducible.
