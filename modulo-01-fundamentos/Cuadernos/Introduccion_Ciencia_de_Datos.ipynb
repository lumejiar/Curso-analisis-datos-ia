# %% [markdown]
# # Módulo 1: Fundamentos de Python para datos
#
# **Curso:** Ciencia de Datos y Analítica Avanzada — Universidad Nacional de Colombia, Sede Palmira
#
# **Contenidos:** Python y Jupyter, estructuras de datos, NumPy.

# %% [markdown]
# ## 1. Introducción a Python y Jupyter
#
# _Contenido por desarrollar._

# %%
# Tu código aquí

# %% [markdown]
# ## 2. Estructuras de datos en Python
#
# Listas, tuplas, diccionarios y conjuntos.
#
# _Contenido por desarrollar._

# %%
# Tu código aquí

# %% [markdown]
# ## 3. Introducción a NumPy
#
# _Contenido por desarrollar._

# %%
import numpy as np

# Tu código aquí

# %% [markdown]
# ## Ejercicios
#
# _Ejercicios por desarrollar._

# %%
# Tu código aquí
